# %%
cd drive/MyDrive/JAIST/Research/RL/task-0203
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/JAIST/Research/RL/task-0203'
# /content/drive/MyDrive/JAIST/Research/RL/task-0203

# %%
from src.DQN.trainer.trainer import DQNtrainer

import yaml
with open('./config/config.yml') as file:
    cfg = yaml.safe_load(file)

# %%
DQNtrainer(cfg)
# Out:
# episode :0, total reward : 10.0, epsilon: 0.1
# episode :10, total reward : 15.0, epsilon: 0.1
# episode :20, total reward : 10.0, epsilon: 0.1
# episode :30, total reward : 19.0, epsilon: 0.1
# episode :40, total reward : 19.0, epsilon: 0.1
# episode :50, total reward : 21.0, epsilon: 0.1
# episode :60, total reward : 33.0, epsilon: 0.1
# episode :70, total reward : 44.0, epsilon: 0.1
# episode :80, total reward : 72.0, epsilon: 0.1
# episode :90, total reward : 21.0, epsilon: 0.1
